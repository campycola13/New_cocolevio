# %%
from flask import Flask, jsonify
from flask_cors import CORS
import pandas as pd
import numpy as np
from datetime import date
from sqlalchemy import create_engine

# %%
engine = create_engine('postgresql://postgres:root@localhost:5432/cocolevio')
query = 'SELECT * FROM "Cocoleviodata"'
df1 = pd.read_sql(query, engine)

# %%
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1832 entries, 0 to 1831
# Data columns (total 16 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Issue key          1832 non-null   object
#  1   Issue id           1832 non-null   int64
#  2   Issue Type         1832 non-null   object
#  3   Project name       1832 non-null   object
#  4   Project lead       1832 non-null   object
#  5   Priority           1832 non-null   object
#  6   Assignee           1768 non-null   object
#  7   Reporter           1832 non-null   object
#  8   Due date           1832 non-null   object
#  9   Description        1248 non-null   object
#  10  Original estimate  1777 non-null   float64
#  11  Time Spent         1832 non-null   int64
#  12  Status Category    1832 non-null   object
#  13  Created            1832 non-null   object
#  14  inward_problem     1832 non-null   int64
#  15  outward_problem    1832 non-null   int64
# ...

# %%
df1['Status Category'].unique()
# Out:
# array(['To Do', 'Done', 'In Progress'], dtype=object)

# %% [markdown]
# df1[df1['Status Category']=='Done'].count()

# %%
df1.sample(10)
# Out:
#       Issue key  Issue id Issue Type Project name       Project lead Priority  \
# 1400   LEVI-939     19623       Task         Levi  Arun Kumar Saxena       P2
# 1308   LEVI-533     19754       Task         Levi  Arun Kumar Saxena       P2
# 904    LEVI-853     20308      Story         Levi  Arun Kumar Saxena       P3
# 681   LEVI-1288     21286       Task         Levi  Arun Kumar Saxena       P2
# 1030   LEVI-747     20136       Task         Levi  Arun Kumar Saxena       P1
# 657   LEVI-1310     21485        Bug         Levi  Arun Kumar Saxena       P2
# 1581   LEVI-294     18797       Test         Levi  Arun Kumar Saxena       P2
# 145   LEVI-1888     25362        Bug         Levi  Arun Kumar Saxena       P2
# 738   LEVI-1225     20829       Task         Levi  Arun Kumar Saxena       P2
# 735   LEVI-1228     20858       Task         Levi  Arun Kumar Saxena       P2
#
#                    Assignee            Reporter          Due date  \
# ...

# %%
df=df1[['Project name' , 'Status Category']]

# %%
len(df)
# Out:
# 1832

# %%
cmplt=len(df[df['Status Category']=='Done'])/len(df)*100

# %%
cmplt
# Out:
# 36.080786026200876

# %%
priority_order = {'P1': 1, 'P2': 2, 'P3': 3 , 'P4':4 , 'Blocker':0}

# %%
df1['priority_num'] = df1['Priority'].map(priority_order)

# %%
df1['Priority'].unique()
# Out:
# array(['P2', 'P1', 'P4', 'P3', 'Blocker'], dtype=object)

# %%
df_sorted = df1.sort_values(by=['outward_problem', 'priority_num'], ascending=[False, True])

# %%
df_sorted.head()
# Out:
#      Issue key  Issue id Issue Type Project name       Project lead Priority  \
# 116  LEVI-1917     25905        Bug         Levi  Arun Kumar Saxena  Blocker
# 436  LEVI-1579     22957        Bug         Levi  Arun Kumar Saxena  Blocker
# 455  LEVI-1562     22940       Task         Levi  Arun Kumar Saxena  Blocker
# 491  LEVI-1522     22838        Bug         Levi  Arun Kumar Saxena  Blocker
# 493  LEVI-1520     22836       Task         Levi  Arun Kumar Saxena  Blocker
#
#                    Assignee               Reporter          Due date  \
# 116   Anand Kumar Chaudhary      Arun Kumar Saxena  11-06-2025 00:00
# 436  Rohit Bhimrao Jondhale      Arun Kumar Saxena  08-06-2025 00:00
# 455  Rohit Bhimrao Jondhale         Shruti Chauhan  13-06-2025 00:00
# 491  Rohit Bhimrao Jondhale        Saugata Chandra  13-06-2025 00:00
# 493   Anand Kumar Chaudhary  Anand Kumar Chaudhary  22-06-2025 00:00
#
#                                            Description  Original estimate  \
# ...

# %%
df1.columns
# Out:
# Index(['Issue key', 'Issue id', 'Issue Type', 'Project name', 'Project lead',
#        'Priority', 'Assignee', 'Reporter', 'Due date', 'Description',
#        'Original estimate', 'Time Spent', 'Status Category', 'Created',
#        'inward_problem', 'outward_problem', 'priority_num'],
#       dtype='object')
